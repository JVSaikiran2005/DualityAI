# %%
# !pip install -q segmentation-models-pytorch albumentations opencv-python tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 2.9 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

TRAIN_ZIP = "/content/drive/MyDrive/Offroad_Segmentation_Training_Dataset.zip"
TEST_ZIP  = "/content/drive/MyDrive/Offroad_Segmentation_testImages.zip"

EXTRACT_PATH = "/content/dataset"

os.makedirs(EXTRACT_PATH, exist_ok=True)

with zipfile.ZipFile(TRAIN_ZIP, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_PATH)

with zipfile.ZipFile(TEST_ZIP, 'r') as zip_ref:
    zip_ref.extractall(EXTRACT_PATH)

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
# !ls /content/dataset
# Out:
# Offroad_Segmentation_testImages  Offroad_Segmentation_Training_Dataset

# %%
TRAIN_IMG_DIR = "/content/dataset/Offroad_Segmentation_Training_Dataset/train/Color_Images"
TRAIN_MASK_DIR = "/content/dataset/Offroad_Segmentation_Training_Dataset/train/Segmentation"

VAL_IMG_DIR = "/content/dataset/Offroad_Segmentation_Training_Dataset/val/Color_Images"
VAL_MASK_DIR = "/content/dataset/Offroad_Segmentation_Training_Dataset/val/Segmentation"

TEST_IMG_DIR = "/content/dataset/Offroad_Segmentation_testImages/Color_Images"

# %%
import os
import cv2
import numpy as np
import torch
import segmentation_models_pytorch as smp
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
def get_unique_colors(mask_dir, sample_limit=100):
    colors = set()
    files = os.listdir(mask_dir)[:sample_limit]

    for file in files:
        mask = cv2.imread(os.path.join(mask_dir, file))
        mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)

        unique = np.unique(mask.reshape(-1, 3), axis=0)
        for color in unique:
            colors.add(tuple(color))

    return sorted(list(colors))


unique_colors = get_unique_colors(TRAIN_MASK_DIR)
NUM_CLASSES = len(unique_colors)

print("Detected Classes:", NUM_CLASSES)
# Out:
# Detected Classes: 6

# %%
COLOR_MAP = {color: idx for idx, color in enumerate(unique_colors)}

def rgb_to_mask(mask):
    h, w, _ = mask.shape
    class_mask = np.zeros((h, w), dtype=np.uint8)

    for rgb, cls in COLOR_MAP.items():
        matches = np.all(mask == rgb, axis=-1)
        class_mask[matches] = cls

    return class_mask

# %%
class OffroadDataset(Dataset):
    def __init__(self, img_dir, mask_dir=None, transform=None):
        self.img_dir = img_dir
        self.mask_dir = mask_dir
        self.images = sorted(os.listdir(img_dir))
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.images[idx])

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        if self.mask_dir:
            mask_path = os.path.join(self.mask_dir, self.images[idx])
            mask = cv2.imread(mask_path)
            mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
            mask = rgb_to_mask(mask)
        else:
            mask = None

        if self.transform:
            if mask is not None:
                augmented = self.transform(image=image, mask=mask)
                image = augmented["image"]
                mask = augmented["mask"]
            else:
                augmented = self.transform(image=image)
                image = augmented["image"]

        if mask is not None:
            return image.float(), mask.long()
        else:
            return image.float(), self.images[idx]

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BATCH_SIZE = 4
EPOCHS = 20
LR = 3e-4
IMAGE_SIZE = 384

# %%
model = smp.DeepLabV3Plus(
    encoder_name="efficientnet-b2",
    encoder_weights="imagenet",
    classes=NUM_CLASSES,
    activation=None,
).to(DEVICE)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/106 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/36.8M [00:00<?, ?B/s]

# %%
train_transform = A.Compose([
    A.Resize(IMAGE_SIZE, IMAGE_SIZE),
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.GaussNoise(p=0.2),
    A.Normalize(),
    ToTensorV2(),
])

val_transform = A.Compose([
    A.Resize(IMAGE_SIZE, IMAGE_SIZE),
    A.Normalize(),
    ToTensorV2(),
])

# %%
train_dataset = OffroadDataset(TRAIN_IMG_DIR, TRAIN_MASK_DIR, train_transform)
val_dataset = OffroadDataset(VAL_IMG_DIR, VAL_MASK_DIR, val_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %%
def compute_class_weights(loader, num_classes):
    pixel_counts = np.zeros(num_classes)

    for images, masks in tqdm(loader):
        masks = masks.numpy()
        for cls in range(num_classes):
            pixel_counts[cls] += np.sum(masks == cls)

    weights = 1.0 / (pixel_counts + 1e-6)
    weights = weights / weights.sum() * num_classes
    return torch.tensor(weights, dtype=torch.float32)

class_weights = compute_class_weights(train_loader, NUM_CLASSES).to(DEVICE)

ce_loss = torch.nn.CrossEntropyLoss(weight=class_weights)
dice_loss = smp.losses.DiceLoss(mode="multiclass")
# Out:
# 100%|██████████| 714/714 [04:27<00:00,  2.67it/s]

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=LR)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="max",
    factor=0.5,
    patience=3
)

scaler = torch.amp.GradScaler(enabled=(DEVICE=="cuda"))

# %%
def compute_per_class_iou(pred, mask):
    pred = torch.argmax(pred, dim=1)
    ious = []

    for cls in range(NUM_CLASSES):
        pred_inds = (pred == cls)
        target_inds = (mask == cls)

        intersection = (pred_inds & target_inds).sum().item()
        union = (pred_inds | target_inds).sum().item()

        if union == 0:
            ious.append(0)
        else:
            ious.append(intersection / union)

    return ious

# %%
best_iou = 0
patience = 5
counter = 0

for epoch in range(EPOCHS):

    model.train()
    train_loss = 0

    for images, masks in tqdm(train_loader):
        images, masks = images.to(DEVICE), masks.to(DEVICE)

        optimizer.zero_grad()

        with torch.cuda.amp.autocast(enabled=(DEVICE=="cuda")):
            preds = model(images)
            loss = dice_loss(preds, masks) + ce_loss(preds, masks)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        train_loss += loss.item()

    model.eval()
    all_class_ious = np.zeros(NUM_CLASSES)

    with torch.no_grad():
        for images, masks in val_loader:
            images, masks = images.to(DEVICE), masks.to(DEVICE)
            preds = model(images)

            class_ious = compute_per_class_iou(preds, masks)
            all_class_ious += np.array(class_ious)

    all_class_ious /= len(val_loader)
    val_iou = np.mean(all_class_ious)

    scheduler.step(val_iou)

    print(f"\nEpoch {epoch+1}")
    print("Train Loss:", train_loss / len(train_loader))
    print("Per-class IoU:", np.round(all_class_ious, 4))
    print("Mean IoU:", val_iou)

    if val_iou > best_iou:
        best_iou = val_iou
        torch.save(model.state_dict(), "best_balanced_model.pth")
        print("Model Improved & Saved")
        counter = 0
    else:
        counter += 1
        if counter >= patience:
            print("Early stopping triggered.")
            break

print("Best IoU:", best_iou)
# Out:
#   0%|          | 0/714 [00:00<?, ?it/s]/tmp/ipython-input-1049/3360852238.py:15: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(DEVICE=="cuda")):
# 100%|██████████| 714/714 [05:09<00:00,  2.30it/s]
# Epoch 1
# Train Loss: 1.5022042153262292
# Per-class IoU: [0.421  0.5092 0.2339 0.1129 0.4063 0.8995]
# Mean IoU: 0.4304484599737921
# Model Improved & Saved
# 100%|██████████| 714/714 [04:54<00:00,  2.42it/s]
# Epoch 2
# Train Loss: 1.234190928752349
# Per-class IoU: [0.4497 0.5483 0.27   0.1546 0.4754 0.8997]
# Mean IoU: 0.46627232656814477
# Model Improved & Saved
# 100%|██████████| 714/714 [04:54<00:00,  2.43it/s]
# Epoch 3
# Train Loss: 1.1606564217922735
# Per-class IoU: [0.4695 0.5616 0.2942 0.1741 0.4942 0.8889]
# Mean IoU: 0.4804101629619762
# Model Improved & Saved
# 100%|██████████| 714/714 [04:51<00:00,  2.45it/s]
# Epoch 4
# Train Loss: 1.1041647285139526
# Per-class IoU: [0.4888 0.5748 0.3129 0.1818 0.5345 0.9031]
# Mean IoU: 0.4993255282602093
# Model Improved & Saved
# 100%|██████████| 714/714 [04:54<00:00,  2.42it/s]
# Epoch 5
# Train Loss: 1.0613734007549553
# Per-class IoU: [0.5121 0.5915 0.3229 0.2214 0.537  0.9025]
# Mean IoU: 0.5145767590873367
# Model Improved & Saved
# 100%|██████████| 714/714 [04:52<00:00,  2.44it/s]
# Epoch 6
# Train Loss: 1.0462110474997877
# Per-class IoU: [0.5347 0.5965 0.3376 0.2251 0.5047 0.8963]
# Mean IoU: 0.5158321917667255
# Model Improved & Saved
# 100%|██████████| 714/714 [04:53<00:00,  2.43it/s]
# Epoch 7
# Train Loss: 1.026566199478315
# Per-class IoU: [0.5422 0.592  0.3379 0.2141 0.5352 0.8923]
# Mean IoU: 0.518948858913201
# Model Improved & Saved
# 100%|██████████| 714/714 [04:52<00:00,  2.44it/s]
# Epoch 8
# Train Loss: 1.0017211991531842
# Per-class IoU: [0.5491 0.5967 0.3475 0.2053 0.5131 0.9022]
# Mean IoU: 0.5189689267169482
# Model Improved & Saved
# 100%|██████████| 714/714 [04:53<00:00,  2.44it/s]
# Epoch 9
# Train Loss: 0.9960518357466582
# Per-class IoU: [0.5634 0.6014 0.3482 0.2327 0.5121 0.9017]
# Mean IoU: 0.526566539803265
# Model Improved & Saved
# 100%|██████████| 714/714 [04:52<00:00,  2.44it/s]
# Epoch 10
# Train Loss: 0.964823541771464
# Per-class IoU: [0.5614 0.6006 0.3548 0.2419 0.5516 0.9026]
# Mean IoU: 0.5354920523016756
# Model Improved & Saved
# 100%|██████████| 714/714 [04:53<00:00,  2.43it/s]
# Epoch 11
# Train Loss: 0.9705614535247579
# Per-class IoU: [0.5627 0.6002 0.3539 0.2373 0.533  0.9026]
# Mean IoU: 0.5316356258539604
# 100%|██████████| 714/714 [04:53<00:00,  2.43it/s]
# Epoch 12
# Train Loss: 0.9560040917550149
# Per-class IoU: [0.5684 0.6008 0.3603 0.243  0.5517 0.9034]
# Mean IoU: 0.5379338274368631
# Model Improved & Saved
# 100%|██████████| 714/714 [04:52<00:00,  2.44it/s]
# Epoch 13
# Train Loss: 0.9442393677074368
# Per-class IoU: [0.5615 0.6024 0.3576 0.2394 0.5197 0.9025]
# Mean IoU: 0.5305074779487855
# 100%|██████████| 714/714 [04:56<00:00,  2.41it/s]
# Epoch 14
# Train Loss: 0.9333639403685134
# Per-class IoU: [0.5791 0.5988 0.3641 0.247  0.5613 0.9036]
# Mean IoU: 0.5423282325572928
# Model Improved & Saved
# 100%|██████████| 714/714 [04:53<00:00,  2.43it/s]
# Epoch 15
# Train Loss: 0.9229958413862714
# Per-class IoU: [0.5928 0.6093 0.3661 0.2549 0.5523 0.9038]
# Mean IoU: 0.5465290346428445
# Model Improved & Saved
# 100%|██████████| 714/714 [04:54<00:00,  2.42it/s]
# Epoch 16
# Train Loss: 0.9293944724634582
# Per-class IoU: [0.586  0.615  0.3652 0.2731 0.5559 0.903 ]
# Mean IoU: 0.5496931894325531
# Model Improved & Saved
# 100%|██████████| 714/714 [04:58<00:00,  2.40it/s]
# Epoch 17
# Train Loss: 0.9159396275752733
# Per-class IoU: [0.5868 0.6153 0.3677 0.2758 0.5662 0.9035]
# Mean IoU: 0.5525386392685588
# Model Improved & Saved
# 100%|██████████| 714/714 [04:55<00:00,  2.41it/s]
# Epoch 18
# Train Loss: 0.901033947280809
# Per-class IoU: [0.5926 0.6133 0.3723 0.2734 0.5515 0.9036]
# Mean IoU: 0.5511043337929353
# 100%|██████████| 714/714 [04:55<00:00,  2.41it/s]
# Epoch 19
# Train Loss: 0.9049016151274619
# Per-class IoU: [0.5944 0.6119 0.3691 0.2724 0.5486 0.9037]
# Mean IoU: 0.5500274081480551
# 100%|██████████| 714/714 [04:57<00:00,  2.40it/s]
# Epoch 20
# Train Loss: 0.8958697651280743
# Per-class IoU: [0.6004 0.6151 0.3728 0.2705 0.5545 0.9037]
# Mean IoU: 0.5528210951948301
# Model Improved & Saved
# Best IoU: 0.5528210951948301

# %%
OUTPUT_DIR = "/content/predictions"
os.makedirs(OUTPUT_DIR, exist_ok=True)

model.eval()

test_dataset = OffroadDataset(TEST_IMG_DIR, transform=val_transform)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

with torch.no_grad():
    for images, names in test_loader:
        images = images.to(DEVICE)
        preds = model(images)

        pred_mask = torch.argmax(preds, dim=1).squeeze().cpu().numpy()

        rgb_mask = np.zeros((pred_mask.shape[0], pred_mask.shape[1], 3), dtype=np.uint8)

        for color, idx in COLOR_MAP.items():
            rgb_mask[pred_mask == idx] = color

        cv2.imwrite(os.path.join(OUTPUT_DIR, names[0]),
                    cv2.cvtColor(rgb_mask, cv2.COLOR_RGB2BGR))

print("Test predictions saved.")
# Out:
# Test predictions saved.

# %%
# !zip -r predictions.zip /content/predictions
# Out:
# updating: content/predictions/ (stored 0%)
# updating: content/predictions/0000582.png (deflated 25%)
# updating: content/predictions/0000105.png (deflated 25%)
# updating: content/predictions/0000977.png (deflated 25%)
# updating: content/predictions/0000491.png (deflated 24%)
# updating: content/predictions/0000459.png (deflated 26%)
# updating: content/predictions/0000324.png (deflated 26%)
# updating: content/predictions/0001044.png (deflated 24%)
# updating: content/predictions/0000572.png (deflated 25%)
# updating: content/predictions/0000222.png (deflated 25%)
# updating: content/predictions/0000060.png (deflated 24%)
# updating: content/predictions/0000609.png (deflated 24%)
# updating: content/predictions/0000544.png (deflated 24%)
# updating: content/predictions/0000090.png (deflated 26%)
# updating: content/predictions/0000687.png (deflated 25%)
# updating: content/predictions/0000608.png (deflated 25%)
# updating: content/predictions/0000412.png (deflated 26%)
# updating: content/predictions/0000627.png (deflated 23%)
# updating: content/predictions/0000614.png (deflated 24%)
# updating: content/predictions/0000312.png (deflated 25%)
# updating: content/predictions/0000353.png (deflated 25%)
# updating: content/predictions/0000846.png (deflated 23%)
# updating: content/predictions/0000510.png (deflated 24%)
# updating: content/predictions/0000429.png (deflated 23%)
# updating: content/predictions/0000619.png (deflated 25%)
# updating: content/predictions/0000902.png (deflated 26%)
# updating: content/predictions/0000615.png (deflated 25%)
# updating: content/predictions/0001060.png (deflated 23%)
# updating: content/predictions/0000994.png (deflated 26%)
# updating: content/predictions/0000487.png (deflated 24%)
# updating: content/predictions/0000626.png (deflated 24%)
# updating: content/predictions/0000551.png (deflated 24%)
# updating: content/predictions/0000456.png (deflated 26%)
# updating: content/predictions/0000822.png (deflated 24%)
# updating: content/predictions/0000733.png (deflated 22%)
# updating: content/predictions/0000640.png (deflated 24%)
# updating: content/predictions/0000698.png (deflated 23%)
# updating: content/predictions/0000829.png (deflated 24%)
# updating: content/predictions/0000161.png (deflated 26%)
# updating: content/predictions/0000307.png (deflated 25%)
# updating: content/predictions/0000135.png (deflated 23%)
# updating: content/predictions/0000531.png (deflated 25%)
# updating: content/predictions/0000901.png (deflated 26%)
# updating: content/predictions/0001005.png (deflated 24%)
# updating: content/predictions/0000935.png (deflated 23%)
# updating: content/predictions/0000779.png (deflated 24%)
# updating: content/predictions/0000477.png (deflated 23%)
# updating: content/predictions/0001030.png (deflated 25%)
# updating: content/predictions/0001012.png (deflated 25%)
# updating: content/predictions/0000211.png (deflated 25%)
# updating: content/predictions/0000878.png (deflated 23%)
# updating: content/predictions/0000588.png (deflated 24%)
# updating: content/predictions/0000306.png (deflated 24%)
# updating: content/predictions/0000508.png (deflated 25%)
# updating: content/predictions/0000786.png (deflated 24%)
# updating: content/predictions/0000503.png (deflated 23%)
# updating: content/predictions/0000916.png (deflated 24%)
# updating: content/predictions/0000318.png (deflated 24%)
# updating: content/predictions/0001036.png (deflated 23%)
# updating: content/predictions/0000171.png (deflated 25%)
# updating: content/predictions/0000723.png (deflated 23%)
# updating: content/predictions/0000892.png (deflated 24%)
# updating: content/predictions/0000906.png (deflated 25%)
# updating: content/predictions/0000521.png (deflated 23%)
# updating: content/predictions/0001042.png (deflated 23%)
# updating: content/predictions/0000871.png (deflated 24%)
# updating: content/predictions/0000954.png (deflated 27%)
# updating: content/predictions/0000895.png (deflated 24%)
# updating: content/predictions/0000579.png (deflated 23%)
# updating: content/predictions/0001046.png (deflated 24%)
# updating: content/predictions/0000367.png (deflated 24%)
# updating: content/predictions/0000841.png (deflated 23%)
# updating: content/predictions/0000104.png (deflated 25%)
# updating: content/predictions/0000377.png (deflated 25%)
# updating: content/predictions/0000269.png (deflated 25%)
# updating: content/predictions/0000625.png (deflated 22%)
# updating: content/predictions/0000115.png (deflated 23%)
# updating: content/predictions/0000987.png (deflated 27%)
# updating: content/predictions/0000793.png (deflated 24%)
# updating: content/predictions/0000898.png (deflated 25%)
# updating: content/predictions/0000325.png (deflated 27%)
# updating: content/predictions/0000759.png (deflated 25%)
# updating: content/predictions/0000160.png (deflated 28%)
# updating: content/predictions/0000853.png (deflated 25%)
# updating: content/predictions/0000195.png (deflated 26%)
# updating: content/predictions/0000489.png (deflated 24%)
# updating: content/predictions/0000907.png (deflated 25%)
# updating: content/predictions/0000849.png (deflated 25%)
# updating: content/predictions/0000815.png (deflated 25%)
# updating: content/predictions/0001045.png (deflated 24%)
# updating: content/predictions/0000976.png (deflated 25%)
# updating: content/predictions/0000140.png (deflated 22%)
# updating: content/predictions/0000460.png (deflated 26%)
# updating: content/predictions/0000877.png (deflated 23%)
# updating: content/predictions/0000434.png (deflated 25%)
# updating: content/predictions/0000500.png (deflated 23%)
# updating: content/predictions/0000766.png (deflated 24%)
# updating: content/predictions/0000737.png (deflated 24%)
# updating: content/predictions/0001020.png (deflated 24%)
# updating: content/predictions/0001006.png (deflated 24%)
# updating: content/predictions/0000897.png (deflated 24%)
# updating: content/predictions/0000758.png (deflated 23%)
# updating: content/predictions/0000537.png (deflated 24%)
# updating: content/predictions/0000712.png (deflated 23%)
# updating: content/predictions/0000944.png (deflated 23%)
# updating: content/predictions/0000812.png (deflated 25%)
# updating: content/predictions/0000890.png (deflated 25%)
# updating: content/predictions/0000798.png (deflated 23%)
# updating: content/predictions/0000643.png (deflated 23%)
# updating: content/predictions/0000630.png (deflated 23%)
# updating: content/predictions/0000168.png (deflated 25%)
# updating: content/predictions/0000231.png (deflated 25%)
# updating: content/predictions/0000336.png (deflated 26%)
# updating: content/predictions/0000283.png (deflated 24%)
# updating: content/predictions/0000662.png (deflated 25%)
# updating: content/predictions/0000738.png (deflated 23%)
# updating: content/predictions/0000855.png (deflated 24%)
# updating: content/predictions/0000294.png (deflated 24%)
# updating: content/predictions/0000753.png (deflated 24%)
# updating: content/predictions/0000911.png (deflated 25%)
# updating: content/predictions/0000611.png (deflated 24%)
# updating: content/predictions/0000300.png (deflated 24%)
# updating: content/predictions/0000357.png (deflated 24%)
# updating: content/predictions/0000857.png (deflated 24%)
# updating: content/predictions/0000827.png (deflated 23%)
# updating: content/predictions/0000236.png (deflated 25%)
# updating: content/predictions/0000560.png (deflated 25%)
# updating: content/predictions/0000703.png (deflated 26%)
# updating: content/predictions/0000690.png (deflated 25%)
# updating: content/predictions/0000436.png (deflated 25%)
# updating: content/predictions/0000142.png (deflated 23%)
# updating: content/predictions/0000838.png (deflated 23%)
# updating: content/predictions/0000134.png (deflated 23%)
# updating: content/predictions/0000437.png (deflated 24%)
# updating: content/predictions/0000595.png (deflated 24%)
# updating: content/predictions/0000641.png (deflated 23%)
# updating: content/predictions/0001022.png (deflated 25%)
# updating: content/predictions/0000529.png (deflated 24%)
# updating: content/predictions/0000549.png (deflated 25%)
# updating: content/predictions/0000480.png (deflated 24%)
# updating: content/predictions/0000078.png (deflated 25%)
# updating: content/predictions/0000230.png (deflated 24%)
# updating: content/predictions/0000702.png (deflated 25%)
# updating: content/predictions/0000438.png (deflated 24%)
# updating: content/predictions/0000660.png (deflated 25%)
# updating: content/predictions/0000320.png (deflated 24%)
# updating: content/predictions/0000392.png (deflated 25%)
# updating: content/predictions/0000704.png (deflated 25%)
# updating: content/predictions/0000993.png (deflated 26%)
# updating: content/predictions/0000931.png (deflated 23%)
# updating: content/predictions/0000780.png (deflated 24%)
# updating: content/predictions/0000141.png (deflated 21%)
# updating: content/predictions/0000674.png (deflated 23%)
# updating: content/predictions/0000929.png (deflated 23%)
# updating: content/predictions/0000351.png (deflated 25%)
# updating: content/predictions/0000586.png (deflated 26%)
# updating: content/predictions/0001016.png (deflated 23%)
# updating: content/predictions/0000959.png (deflated 26%)
# updating: content/predictions/0000478.png (deflated 25%)
# updating: content/predictions/0000856.png (deflated 25%)
# updating: content/predictions/0000656.png (deflated 25%)
# updating: content/predictions/0000519.png (deflated 24%)
# updating: content/predictions/0000511.png (deflated 24%)
# updating: content/predictions/0000194.png (deflated 26%)
# updating: content/predictions/0000455.png (deflated 25%)
# updating: content/predictions/0000210.png (deflated 23%)
# updating: content/predictions/0000110.png (deflated 24%)
# updating: content/predictions/0000196.png (deflated 25%)
# updating: content/predictions/0000734.png (deflated 22%)
# updating: content/predictions/0000658.png (deflated 25%)
# updating: content/predictions/0000893.png (deflated 24%)
# updating: content/predictions/0001027.png (deflated 25%)
# updating: content/predictions/0000401.png (deflated 25%)
# updating: content/predictions/0000720.png (deflated 23%)
# updating: content/predictions/0000749.png (deflated 23%)
# updating: content/predictions/0000108.png (deflated 25%)
# updating: content/predictions/0000880.png (deflated 24%)
# updating: content/predictions/0000695.png (deflated 24%)
# updating: content/predictions/0000576.png (deflated 24%)
# updating: content/predictions/0000279.png (deflated 23%)
# updating: content/predictions/0000762.png (deflated 24%)
# updating: content/predictions/0001059.png (deflated 23%)
# updating: content/predictions/0000347.png (deflated 25%)
# updating: content/predictions/0000496.png (deflated 25%)
# updating: content/predictions/0000154.png (deflated 23%)
# updating: content/predictions/0000415.png (deflated 26%)
# updating: content/predictions/0000375.png (deflated 24%)
# updating: content/predictions/0000732.png (deflated 23%)
# updating: content/predictions/0000261.png (deflated 24%)
# updating: content/predictions/0000216.png (deflated 24%)
# updating: content/predictions/0000284.png (deflated 23%)
# updating: content/predictions/0000241.png (deflated 23%)
# updating: content/predictions/0000243.png (deflated 24%)
# updating: content/predictions/0000975.png (deflated 25%)
# updating: content/predictions/0000286.png (deflated 23%)
# updating: content/predictions/0000700.png (deflated 25%)
# updating: content/predictions/0000525.png (deflated 24%)
# updating: content/predictions/0000254.png (deflated 22%)
# updating: content/predictions/0000654.png (deflated 25%)
# updating: content/predictions/0000523.png (deflated 25%)
# updating: content/predictions/0000574.png (deflated 25%)
# updating: content/predictions/0000281.png (deflated 25%)
# updating: content/predictions/0000378.png (deflated 25%)
# updating: content/predictions/0000470.png (deflated 25%)
# updating: content/predictions/0000774.png (deflated 24%)
# updating: content/predictions/0000327.png (deflated 26%)
# updating: content/predictions/0000209.png (deflated 24%)
# updating: content/predictions/0000701.png (deflated 24%)
# updating: content/predictions/0000807.png (deflated 26%)
# updating: content/predictions/0000063.png (deflated 24%)
# updating: content/predictions/0000869.png (deflated 24%)
# updating: content/predictions/0000374.png (deflated 25%)
# updating: content/predictions/0000578.png (deflated 24%)
# updating: content/predictions/0000466.png (deflated 26%)
# updating: content/predictions/0000206.png (deflated 25%)
# updating: content/predictions/0001021.png (deflated 25%)
# updating: content/predictions/0000905.png (deflated 25%)
# updating: content/predictions/0000921.png (deflated 26%)
# updating: content/predictions/0000397.png (deflated 25%)
# updating: content/predictions/0000711.png (deflated 23%)
# updating: content/predictions/0000850.png (deflated 24%)
# updating: content/predictions/0000358.png (deflated 25%)
# updating: content/predictions/0000163.png (deflated 26%)
# updating: content/predictions/0001014.png (deflated 26%)
# updating: content/predictions/0000639.png (deflated 25%)
# updating: content/predictions/0000106.png (deflated 25%)
# updating: content/predictions/0000526.png (deflated 24%)
# updating: content/predictions/0000873.png (deflated 23%)
# updating: content/predictions/0000322.png (deflated 24%)
# updating: content/predictions/0000431.png (deflated 25%)
# updating: content/predictions/0000541.png (deflated 25%)
# updating: content/predictions/0000811.png (deflated 25%)
# updating: content/predictions/0000156.png (deflated 25%)
# updating: content/predictions/0000960.png (deflated 26%)
# updating: content/predictions/0000865.png (deflated 24%)
# updating: content/predictions/0000713.png (deflated 24%)
# updating: content/predictions/0000445.png (deflated 25%)
# updating: content/predictions/0000948.png (deflated 23%)
# updating: content/predictions/0000155.png (deflated 23%)
# updating: content/predictions/0001057.png (deflated 25%)
# updating: content/predictions/0000313.png (deflated 25%)
# updating: content/predictions/0000730.png (deflated 23%)
# updating: content/predictions/0000182.png (deflated 26%)
# updating: content/predictions/0000359.png (deflated 25%)
# updating: content/predictions/0000825.png (deflated 23%)
# updating: content/predictions/0000688.png (deflated 24%)
# updating: content/predictions/0000100.png (deflated 25%)
# updating: content/predictions/0001034.png (deflated 25%)
# updating: content/predictions/0000400.png (deflated 25%)
# updating: content/predictions/0000287.png (deflated 23%)
# updating: content/predictions/0000653.png (deflated 25%)
# updating: content/predictions/0000119.png (deflated 22%)
# updating: content/predictions/0000422.png (deflated 24%)
# updating: content/predictions/0000604.png (deflated 24%)
# updating: content/predictions/0000187.png (deflated 26%)
# updating: content/predictions/0000311.png (deflated 25%)
# updating: content/predictions/0000866.png (deflated 24%)
# updating: content/predictions/0000094.png (deflated 26%)
# updating: content/predictions/0000961.png (deflated 26%)
# updating: content/predictions/0000896.png (deflated 25%)
# updating: content/predictions/0000598.png (deflated 23%)
# updating: content/predictions/0000159.png (deflated 28%)
# updating: content/predictions/0000760.png (deflated 24%)
# updating: content/predictions/0000719.png (deflated 23%)
# updating: content/predictions/0000522.png (deflated 24%)
# updating: content/predictions/0000130.png (deflated 23%)
# updating: content/predictions/0000947.png (deflated 23%)
# updating: content/predictions/0000580.png (deflated 25%)
# updating: content/predictions/0000297.png (deflated 24%)
# updating: content/predictions/0000520.png (deflated 23%)
# updating: content/predictions/0000229.png (deflated 25%)
# updating: content/predictions/0000075.png (deflated 25%)
# updating: content/predictions/0000381.png (deflated 24%)
# updating: content/predictions/0000818.png (deflated 24%)
# updating: content/predictions/0000530.png (deflated 24%)
# updating: content/predictions/0000121.png (deflated 23%)
# updating: content/predictions/0000128.png (deflated 21%)
# updating: content/predictions/0000148.png (deflated 23%)
# updating: content/predictions/0000424.png (deflated 25%)
# updating: content/predictions/0000383.png (deflated 25%)
# updating: content/predictions/0000716.png (deflated 23%)
# updating: content/predictions/0000605.png (deflated 25%)
# updating: content/predictions/0000646.png (deflated 24%)
# updating: content/predictions/0000596.png (deflated 24%)
# updating: content/predictions/0000670.png (deflated 25%)
# updating: content/predictions/0001047.png (deflated 23%)
# updating: content/predictions/0000454.png (deflated 23%)
# updating: content/predictions/0000314.png (deflated 24%)
# updating: content/predictions/0000067.png (deflated 23%)
# updating: content/predictions/0000402.png (deflated 24%)
# updating: content/predictions/0001043.png (deflated 24%)
# updating: content/predictions/0000393.png (deflated 24%)
# updating: content/predictions/0000150.png (deflated 23%)
# updating: content/predictions/0000721.png (deflated 22%)
# updating: content/predictions/0000512.png (deflated 24%)
# updating: content/predictions/0000441.png (deflated 25%)
# updating: content/predictions/0000225.png (deflated 23%)
# updating: content/predictions/0000573.png (deflated 24%)
# updating: content/predictions/0000091.png (deflated 25%)
# updating: content/predictions/0000633.png (deflated 24%)
# updating: content/predictions/0000918.png (deflated 24%)
# updating: content/predictions/0000543.png (deflated 25%)
# updating: content/predictions/0000103.png (deflated 24%)
# updating: content/predictions/0000080.png (deflated 25%)
# updating: content/predictions/0000851.png (deflated 25%)
# updating: content/predictions/0000552.png (deflated 26%)
# updating: content/predictions/0000804.png (deflated 26%)
# updating: content/predictions/0000826.png (deflated 24%)
# updating: content/predictions/0000836.png (deflated 24%)
# updating: content/predictions/0000277.png (deflated 24%)
# updating: content/predictions/0000488.png (deflated 24%)
# updating: content/predictions/0000275.png (deflated 25%)
# updating: content/predictions/0000066.png (deflated 23%)
# updating: content/predictions/0000264.png (deflated 24%)
# updating: content/predictions/0000970.png (deflated 24%)
# updating: content/predictions/0000814.png (deflated 25%)
# updating: content/predictions/0000735.png (deflated 23%)
# updating: content/predictions/0000979.png (deflated 25%)
# updating: content/predictions/0000411.png (deflated 25%)
# updating: content/predictions/0000844.png (deflated 24%)
# updating: content/predictions/0000816.png (deflated 24%)
# updating: content/predictions/0000791.png (deflated 24%)
# updating: content/predictions/0001002.png (deflated 24%)
# updating: content/predictions/0000981.png (deflated 25%)
# updating: content/predictions/0000988.png (deflated 25%)
# updating: content/predictions/0000435.png (deflated 25%)
# updating: content/predictions/0000395.png (deflated 25%)
# updating: content/predictions/0000752.png (deflated 23%)
# updating: content/predictions/0000571.png (deflated 25%)
# updating: content/predictions/0001037.png (deflated 23%)
# updating: content/predictions/0001023.png (deflated 26%)
# updating: content/predictions/0000768.png (deflated 24%)
# updating: content/predictions/0000725.png (deflated 22%)
# updating: content/predictions/0001024.png (deflated 25%)
# updating: content/predictions/0000473.png (deflated 26%)
# updating: content/predictions/0000071.png (deflated 22%)
# updating: content/predictions/0000628.png (deflated 23%)
# updating: content/predictions/0000726.png (deflated 25%)
# updating: content/predictions/0000073.png (deflated 23%)
# updating: content/predictions/0001018.png (deflated 24%)
# updating: content/predictions/0000837.png (deflated 23%)
# updating: content/predictions/0000413.png (deflated 26%)
# updating: content/predictions/0000420.png (deflated 25%)
# updating: content/predictions/0000828.png (deflated 24%)
# updating: content/predictions/0000810.png (deflated 27%)
# updating: content/predictions/0000083.png (deflated 24%)
# updating: content/predictions/0000763.png (deflated 25%)
# updating: content/predictions/0000739.png (deflated 22%)
# updating: content/predictions/0000089.png (deflated 27%)
# updating: content/predictions/0000153.png (deflated 24%)
# updating: content/predictions/0000341.png (deflated 25%)
# updating: content/predictions/0000126.png (deflated 24%)
# updating: content/predictions/0000183.png (deflated 25%)
# updating: content/predictions/0000372.png (deflated 24%)
# updating: content/predictions/0000659.png (deflated 25%)
# updating: content/predictions/0000968.png (deflated 26%)
# updating: content/predictions/0001017.png (deflated 23%)
# updating: content/predictions/0000143.png (deflated 23%)
# updating: content/predictions/0000166.png (deflated 25%)
# updating: content/predictions/0000834.png (deflated 25%)
# updating: content/predictions/0000554.png (deflated 25%)
# updating: content/predictions/0000167.png (deflated 25%)
# updating: content/predictions/0000930.png (deflated 24%)
# updating: content/predictions/0000801.png (deflated 24%)
# updating: content/predictions/0000340.png (deflated 25%)
# updating: content/predictions/0000621.png (deflated 24%)
# updating: content/predictions/0000997.png (deflated 25%)
# updating: content/predictions/0000410.png (deflated 24%)
# updating: content/predictions/0000129.png (deflated 23%)
# updating: content/predictions/0000326.png (deflated 25%)
# updating: content/predictions/0000914.png (deflated 24%)
# updating: content/predictions/0000178.png (deflated 26%)
# updating: content/predictions/0000132.png (deflated 23%)
# updating: content/predictions/0000164.png (deflated 24%)
# updating: content/predictions/0000666.png (deflated 25%)
# updating: content/predictions/0000181.png (deflated 25%)
# updating: content/predictions/0000920.png (deflated 24%)
# updating: content/predictions/0000093.png (deflated 26%)
# updating: content/predictions/0000087.png (deflated 25%)
# updating: content/predictions/0001019.png (deflated 25%)
# updating: content/predictions/0000498.png (deflated 24%)
# updating: content/predictions/0001004.png (deflated 25%)
# updating: content/predictions/0000632.png (deflated 24%)
# updating: content/predictions/0000486.png (deflated 23%)
# updating: content/predictions/0000652.png (deflated 24%)
# updating: content/predictions/0000787.png (deflated 24%)
# updating: content/predictions/0001056.png (deflated 25%)
# updating: content/predictions/0000061.png (deflated 24%)
# updating: content/predictions/0000146.png (deflated 24%)
# updating: content/predictions/0000874.png (deflated 22%)
# updating: content/predictions/0000567.png (deflated 25%)
# updating: content/predictions/0000782.png (deflated 24%)
# updating: content/predictions/0000731.png (deflated 22%)
# updating: content/predictions/0000514.png (deflated 24%)
# updating: content/predictions/0000956.png (deflated 28%)
# updating: content/predictions/0000996.png (deflated 24%)
# updating: content/predictions/0000624.png (deflated 23%)
# updating: content/predictions/0001050.png (deflated 24%)
# updating: content/predictions/0000565.png (deflated 26%)
# updating: content/predictions/0000098.png (deflated 24%)
# updating: content/predictions/0000425.png (deflated 24%)
# updating: content/predictions/0000955.png (deflated 26%)
# updating: content/predictions/0000190.png (deflated 25%)
# updating: content/predictions/0000875.png (deflated 22%)
# updating: content/predictions/0000234.png (deflated 25%)
# updating: content/predictions/0000421.png (deflated 23%)
# updating: content/predictions/0000863.png (deflated 24%)
# updating: content/predictions/0000212.png (deflated 24%)
# updating: content/predictions/0000806.png (deflated 25%)
# updating: content/predictions/0001028.png (deflated 24%)
# updating: content/predictions/0000432.png (deflated 25%)
# updating: content/predictions/0000361.png (deflated 25%)
# updating: content/predictions/0000908.png (deflated 25%)
# updating: content/predictions/0000622.png (deflated 23%)
# updating: content/predictions/0000555.png (deflated 25%)
# updating: content/predictions/0000862.png (deflated 23%)
# updating: content/predictions/0000962.png (deflated 26%)
# updating: content/predictions/0000963.png (deflated 26%)
# updating: content/predictions/0000339.png (deflated 25%)
# updating: content/predictions/0001052.png (deflated 23%)
# updating: content/predictions/0000676.png (deflated 23%)
# updating: content/predictions/0000683.png (deflated 23%)
# updating: content/predictions/0000189.png (deflated 24%)
# updating: content/predictions/0000972.png (deflated 25%)
# updating: content/predictions/0000516.png (deflated 24%)
# updating: content/predictions/0000451.png (deflated 26%)
# updating: content/predictions/0000276.png (deflated 24%)
# updating: content/predictions/0000102.png (deflated 25%)
# updating: content/predictions/0000356.png (deflated 26%)
# updating: content/predictions/0000305.png (deflated 25%)
# updating: content/predictions/0000966.png (deflated 25%)
# updating: content/predictions/0000705.png (deflated 25%)
# updating: content/predictions/0000729.png (deflated 23%)
# updating: content/predictions/0000280.png (deflated 23%)
# updating: content/predictions/0000262.png (deflated 23%)
# updating: content/predictions/0000678.png (deflated 23%)
# updating: content/predictions/0000133.png (deflated 23%)
# updating: content/predictions/0000564.png (deflated 26%)
# updating: content/predictions/0000233.png (deflated 25%)
# updating: content/predictions/0000709.png (deflated 24%)
# updating: content/predictions/0001041.png (deflated 23%)
# updating: content/predictions/0000349.png (deflated 24%)
# updating: content/predictions/0000989.png (deflated 27%)
# updating: content/predictions/0000532.png (deflated 25%)
# updating: content/predictions/0000384.png (deflated 23%)
# updating: content/predictions/0000800.png (deflated 23%)
# updating: content/predictions/0000198.png (deflated 25%)
# updating: content/predictions/0000832.png (deflated 23%)
# updating: content/predictions/0000095.png (deflated 26%)
# updating: content/predictions/0000773.png (deflated 24%)
# updating: content/predictions/0000235.png (deflated 25%)
# updating: content/predictions/0000363.png (deflated 24%)
# updating: content/predictions/0000833.png (deflated 24%)
# updating: content/predictions/0000922.png (deflated 24%)
# updating: content/predictions/0000404.png (deflated 26%)
# updating: content/predictions/0000330.png (deflated 25%)
# updating: content/predictions/0000680.png (deflated 22%)
# updating: content/predictions/0000256.png (deflated 23%)
# updating: content/predictions/0000244.png (deflated 24%)
# updating: content/predictions/0000329.png (deflated 26%)
# updating: content/predictions/0000673.png (deflated 24%)
# updating: content/predictions/0000648.png (deflated 26%)
# updating: content/predictions/0000938.png (deflated 23%)
# updating: content/predictions/0000217.png (deflated 26%)
# updating: content/predictions/0000767.png (deflated 24%)
# updating: content/predictions/0000718.png (deflated 23%)
# updating: content/predictions/0000562.png (deflated 27%)
# updating: content/predictions/0000260.png (deflated 24%)
# updating: content/predictions/0000881.png (deflated 24%)
# updating: content/predictions/0000612.png (deflated 24%)
# updating: content/predictions/0000069.png (deflated 24%)
# updating: content/predictions/0000934.png (deflated 24%)
# updating: content/predictions/0000789.png (deflated 24%)
# updating: content/predictions/0000193.png (deflated 26%)
# updating: content/predictions/0000965.png (deflated 26%)
# updating: content/predictions/0000169.png (deflated 25%)
# updating: content/predictions/0000109.png (deflated 24%)
# updating: content/predictions/0000226.png (deflated 24%)
# updating: content/predictions/0000504.png (deflated 24%)
# updating: content/predictions/0000986.png (deflated 26%)
# updating: content/predictions/0000681.png (deflated 23%)
# updating: content/predictions/0000123.png (deflated 23%)
# updating: content/predictions/0000909.png (deflated 24%)
# updating: content/predictions/0000416.png (deflated 25%)
# updating: content/predictions/0000494.png (deflated 25%)
# updating: content/predictions/0000808.png (deflated 25%)
# updating: content/predictions/0000373.png (deflated 24%)
# updating: content/predictions/0000077.png (deflated 25%)
# updating: content/predictions/0000594.png (deflated 23%)
# updating: content/predictions/0000650.png (deflated 25%)
# updating: content/predictions/0000602.png (deflated 23%)
# updating: content/predictions/0000783.png (deflated 24%)
# updating: content/predictions/0000490.png (deflated 22%)
# updating: content/predictions/0000199.png (deflated 25%)
# updating: content/predictions/0000913.png (deflated 24%)
# updating: content/predictions/0000848.png (deflated 23%)
# updating: content/predictions/0000495.png (deflated 25%)
# updating: content/predictions/0000099.png (deflated 24%)
# updating: content/predictions/0000867.png (deflated 23%)
# updating: content/predictions/0000561.png (deflated 25%)
# updating: content/predictions/0000082.png (deflated 24%)
# updating: content/predictions/0000228.png (deflated 24%)
# updating: content/predictions/0000937.png (deflated 22%)
# updating: content/predictions/0000584.png (deflated 24%)
# updating: content/predictions/0000748.png (deflated 23%)
# updating: content/predictions/0000362.png (deflated 26%)
# updating: content/predictions/0000618.png (deflated 24%)
# updating: content/predictions/0000858.png (deflated 24%)
# updating: content/predictions/0000483.png (deflated 23%)
# updating: content/predictions/0000904.png (deflated 25%)
# updating: content/predictions/0000085.png (deflated 24%)
# updating: content/predictions/0000449.png (deflated 26%)
# updating: content/predictions/0000484.png (deflated 23%)
# updating: content/predictions/0000174.png (deflated 25%)
# updating: content/predictions/0000860.png (deflated 22%)
# updating: content/predictions/0000116.png (deflated 23%)
# updating: content/predictions/0000282.png (deflated 24%)
# updating: content/predictions/0000203.png (deflated 25%)
# updating: content/predictions/0000255.png (deflated 23%)
# updating: content/predictions/0000553.png (deflated 25%)
# updating: content/predictions/0000355.png (deflated 25%)
# updating: content/predictions/0000065.png (deflated 22%)
# updating: content/predictions/0000949.png (deflated 24%)
# updating: content/predictions/0000191.png (deflated 25%)
# updating: content/predictions/0000559.png (deflated 26%)
# updating: content/predictions/0000406.png (deflated 24%)
# updating: content/predictions/0000933.png (deflated 23%)
# updating: content/predictions/0000528.png (deflated 25%)
# updating: content/predictions/0000840.png (deflated 23%)
# updating: content/predictions/0000542.png (deflated 25%)
# updating: content/predictions/0000771.png (deflated 25%)
# updating: content/predictions/0000232.png (deflated 26%)
# updating: content/predictions/0001007.png (deflated 25%)
# updating: content/predictions/0000509.png (deflated 25%)
# updating: content/predictions/0000137.png (deflated 22%)
# updating: content/predictions/0000581.png (deflated 25%)
# updating: content/predictions/0000764.png (deflated 26%)
# updating: content/predictions/0000463.png (deflated 25%)
# updating: content/predictions/0000139.png (deflated 22%)
# updating: content/predictions/0001039.png (deflated 24%)
# updating: content/predictions/0000591.png (deflated 26%)
# updating: content/predictions/0000334.png (deflated 25%)
# updating: content/predictions/0000845.png (deflated 23%)
# updating: content/predictions/0000545.png (deflated 25%)
# updating: content/predictions/0000706.png (deflated 25%)
# updating: content/predictions/0000936.png (deflated 23%)
# updating: content/predictions/0000368.png (deflated 24%)
# updating: content/predictions/0000333.png (deflated 25%)
# updating: content/predictions/0000839.png (deflated 24%)
# updating: content/predictions/0000868.png (deflated 24%)
# updating: content/predictions/0000536.png (deflated 24%)
# updating: content/predictions/0001031.png (deflated 25%)
# updating: content/predictions/0000207.png (deflated 24%)
# updating: content/predictions/0000891.png (deflated 25%)
# updating: content/predictions/0000556.png (deflated 25%)
# updating: content/predictions/0000784.png (deflated 24%)
# updating: content/predictions/0000589.png (deflated 26%)
# updating: content/predictions/0000821.png (deflated 25%)
# updating: content/predictions/0000482.png (deflated 23%)
# updating: content/predictions/0000570.png (deflated 25%)
# updating: content/predictions/0000144.png (deflated 23%)
# updating: content/predictions/0001015.png (deflated 24%)
# updating: content/predictions/0000736.png (deflated 23%)
# updating: content/predictions/0000258.png (deflated 22%)
# updating: content/predictions/0000296.png (deflated 23%)
# updating: content/predictions/0000663.png (deflated 24%)
# updating: content/predictions/0000302.png (deflated 24%)
# updating: content/predictions/0000505.png (deflated 24%)
# updating: content/predictions/0001003.png (deflated 24%)
# updating: content/predictions/0000790.png (deflated 24%)
# updating: content/predictions/0000070.png (deflated 23%)
# updating: content/predictions/0000125.png (deflated 23%)
# updating: content/predictions/0000583.png (deflated 26%)
# updating: content/predictions/0000603.png (deflated 24%)
# updating: content/predictions/0001032.png (deflated 25%)
# updating: content/predictions/0000202.png (deflated 24%)
# updating: content/predictions/0000175.png (deflated 26%)
# updating: content/predictions/0001051.png (deflated 24%)
# updating: content/predictions/0001009.png (deflated 24%)
# updating: content/predictions/0000152.png (deflated 24%)
# updating: content/predictions/0001011.png (deflated 22%)
# updating: content/predictions/0000213.png (deflated 25%)
# updating: content/predictions/0000953.png (deflated 27%)
# updating: content/predictions/0000885.png (deflated 25%)
# updating: content/predictions/0000165.png (deflated 25%)
# updating: content/predictions/0000610.png (deflated 24%)
# updating: content/predictions/0000661.png (deflated 25%)
# updating: content/predictions/0000635.png (deflated 22%)
# updating: content/predictions/0000120.png (deflated 22%)
# updating: content/predictions/0000900.png (deflated 26%)
# updating: content/predictions/0000889.png (deflated 22%)
# updating: content/predictions/0000967.png (deflated 25%)
# updating: content/predictions/0000107.png (deflated 25%)
# updating: content/predictions/0000842.png (deflated 23%)
# updating: content/predictions/0000778.png (deflated 24%)
# updating: content/predictions/0000707.png (deflated 25%)
# updating: content/predictions/0000430.png (deflated 24%)
# updating: content/predictions/0000396.png (deflated 25%)
# updating: content/predictions/0000423.png (deflated 25%)
# updating: content/predictions/0000452.png (deflated 26%)
# updating: content/predictions/0000872.png (deflated 23%)
# updating: content/predictions/0000081.png (deflated 25%)
# updating: content/predictions/0000925.png (deflated 25%)
# updating: content/predictions/0000068.png (deflated 23%)
# updating: content/predictions/0000952.png (deflated 27%)
# updating: content/predictions/0000214.png (deflated 25%)
# updating: content/predictions/0000642.png (deflated 25%)
# updating: content/predictions/0000819.png (deflated 25%)
# updating: content/predictions/0000064.png (deflated 24%)
# updating: content/predictions/0001001.png (deflated 24%)
# updating: content/predictions/0000669.png (deflated 24%)
# updating: content/predictions/0000439.png (deflated 24%)
# updating: content/predictions/0000270.png (deflated 24%)
# updating: content/predictions/0000369.png (deflated 22%)
# updating: content/predictions/0000408.png (deflated 25%)
# updating: content/predictions/0000138.png (deflated 22%)
# updating: content/predictions/0000301.png (deflated 25%)
# updating: content/predictions/0000259.png (deflated 23%)
# updating: content/predictions/0000173.png (deflated 25%)
# updating: content/predictions/0000267.png (deflated 23%)
# updating: content/predictions/0000479.png (deflated 24%)
# updating: content/predictions/0000699.png (deflated 25%)
# updating: content/predictions/0000391.png (deflated 24%)
# updating: content/predictions/0000667.png (deflated 25%)
# updating: content/predictions/0000407.png (deflated 24%)
# updating: content/predictions/0000157.png (deflated 26%)
# updating: content/predictions/0000427.png (deflated 23%)
# updating: content/predictions/0000239.png (deflated 24%)
# updating: content/predictions/0000710.png (deflated 25%)
# updating: content/predictions/0000903.png (deflated 25%)
# updating: content/predictions/0000750.png (deflated 23%)
# updating: content/predictions/0000386.png (deflated 23%)
# updating: content/predictions/0000208.png (deflated 23%)
# updating: content/predictions/0000677.png (deflated 23%)
# updating: content/predictions/0000418.png (deflated 24%)
# updating: content/predictions/0000717.png (deflated 22%)
# updating: content/predictions/0000316.png (deflated 25%)
# updating: content/predictions/0000647.png (deflated 26%)
# updating: content/predictions/0000385.png (deflated 24%)
# updating: content/predictions/0000370.png (deflated 23%)
# updating: content/predictions/0000691.png (deflated 25%)
# updating: content/predictions/0000394.png (deflated 24%)
# updating: content/predictions/0000426.png (deflated 24%)
# updating: content/predictions/0000631.png (deflated 23%)
# updating: content/predictions/0000722.png (deflated 23%)
# updating: content/predictions/0000876.png (deflated 23%)
# updating: content/predictions/0001054.png (deflated 24%)
# updating: content/predictions/0000151.png (deflated 24%)
# updating: content/predictions/0000817.png (deflated 25%)
# updating: content/predictions/0000309.png (deflated 25%)
# updating: content/predictions/0000644.png (deflated 23%)
# updating: content/predictions/0000242.png (deflated 24%)
# updating: content/predictions/0000879.png (deflated 23%)
# updating: content/predictions/0000084.png (deflated 25%)
# updating: content/predictions/0001013.png (deflated 25%)
# updating: content/predictions/0000461.png (deflated 24%)
# updating: content/predictions/0000637.png (deflated 24%)
# updating: content/predictions/0000917.png (deflated 24%)
# updating: content/predictions/0000467.png (deflated 25%)
# updating: content/predictions/0000864.png (deflated 24%)
# updating: content/predictions/0000585.png (deflated 25%)
# updating: content/predictions/0000097.png (deflated 25%)
# updating: content/predictions/0000266.png (deflated 23%)
# updating: content/predictions/0000513.png (deflated 24%)
# updating: content/predictions/0000742.png (deflated 22%)
# updating: content/predictions/0001040.png (deflated 24%)
# updating: content/predictions/0000271.png (deflated 24%)
# updating: content/predictions/0000854.png (deflated 23%)
# updating: content/predictions/0000409.png (deflated 25%)
# updating: content/predictions/0000444.png (deflated 25%)
# updating: content/predictions/0000319.png (deflated 24%)
# updating: content/predictions/0000382.png (deflated 24%)
# updating: content/predictions/0000338.png (deflated 26%)
# updating: content/predictions/0001008.png (deflated 24%)
# updating: content/predictions/0000629.png (deflated 23%)
# updating: content/predictions/0000506.png (deflated 25%)
# updating: content/predictions/0000180.png (deflated 24%)
# updating: content/predictions/0000389.png (deflated 23%)
# updating: content/predictions/0000299.png (deflated 23%)
# updating: content/predictions/0000268.png (deflated 25%)
# updating: content/predictions/0000088.png (deflated 26%)
# updating: content/predictions/0000343.png (deflated 24%)
# updating: content/predictions/0000321.png (deflated 23%)
# updating: content/predictions/0000747.png (deflated 22%)
# updating: content/predictions/0000785.png (deflated 24%)
# updating: content/predictions/0000724.png (deflated 24%)
# updating: content/predictions/0000803.png (deflated 25%)
# updating: content/predictions/0000197.png (deflated 26%)
# updating: content/predictions/0000668.png (deflated 25%)
# updating: content/predictions/0000886.png (deflated 25%)
# updating: content/predictions/0000926.png (deflated 25%)
# updating: content/predictions/0000265.png (deflated 23%)
# updating: content/predictions/0001033.png (deflated 25%)
# updating: content/predictions/0000458.png (deflated 27%)
# updating: content/predictions/0000665.png (deflated 23%)
# updating: content/predictions/0000403.png (deflated 25%)
# updating: content/predictions/0000515.png (deflated 24%)
# updating: content/predictions/0000761.png (deflated 25%)
# updating: content/predictions/0000769.png (deflated 25%)
# updating: content/predictions/0000859.png (deflated 25%)
# updating: content/predictions/0000990.png (deflated 26%)
# updating: content/predictions/0000443.png (deflated 24%)
# updating: content/predictions/0000200.png (deflated 25%)
# updating: content/predictions/0000708.png (deflated 26%)
# updating: content/predictions/0000995.png (deflated 24%)
# updating: content/predictions/0000366.png (deflated 24%)
# updating: content/predictions/0000675.png (deflated 23%)
# updating: content/predictions/0000253.png (deflated 22%)
# updating: content/predictions/0000419.png (deflated 25%)
# updating: content/predictions/0000497.png (deflated 23%)
# updating: content/predictions/0000184.png (deflated 25%)
# updating: content/predictions/0000870.png (deflated 25%)
# updating: content/predictions/0000342.png (deflated 24%)
# updating: content/predictions/0000433.png (deflated 25%)
# updating: content/predictions/0000728.png (deflated 24%)
# updating: content/predictions/0000915.png (deflated 24%)
# updating: content/predictions/0000882.png (deflated 24%)
# updating: content/predictions/0001055.png (deflated 24%)
# updating: content/predictions/0001000.png (deflated 25%)
# updating: content/predictions/0000781.png (deflated 24%)
# updating: content/predictions/0000304.png (deflated 24%)
# updating: content/predictions/0000888.png (deflated 22%)
# updating: content/predictions/0000465.png (deflated 26%)
# updating: content/predictions/0000364.png (deflated 23%)
# updating: content/predictions/0001061.png (deflated 24%)
# updating: content/predictions/0000350.png (deflated 25%)
# updating: content/predictions/0001053.png (deflated 24%)
# updating: content/predictions/0000524.png (deflated 25%)
# updating: content/predictions/0000499.png (deflated 24%)
# updating: content/predictions/0000861.png (deflated 23%)
# updating: content/predictions/0000440.png (deflated 26%)
# updating: content/predictions/0000547.png (deflated 25%)
# updating: content/predictions/0000946.png (deflated 24%)
# updating: content/predictions/0000600.png (deflated 24%)
# updating: content/predictions/0000843.png (deflated 24%)
# updating: content/predictions/0000323.png (deflated 25%)
# updating: content/predictions/0000114.png (deflated 24%)
# updating: content/predictions/0000757.png (deflated 23%)
# updating: content/predictions/0000649.png (deflated 25%)
# updating: content/predictions/0000428.png (deflated 24%)
# updating: content/predictions/0000252.png (deflated 23%)
# updating: content/predictions/0000645.png (deflated 24%)
# updating: content/predictions/0000939.png (deflated 23%)
# updating: content/predictions/0000348.png (deflated 25%)
# updating: content/predictions/0000315.png (deflated 24%)
# updating: content/predictions/0000950.png (deflated 26%)
# updating: content/predictions/0000072.png (deflated 23%)
# updating: content/predictions/0000308.png (deflated 25%)
# updating: content/predictions/0000476.png (deflated 25%)
# updating: content/predictions/0000502.png (deflated 24%)
# updating: content/predictions/0000755.png (deflated 23%)
# updating: content/predictions/0000136.png (deflated 23%)
# updating: content/predictions/0000777.png (deflated 24%)
# updating: content/predictions/0000924.png (deflated 24%)
# updating: content/predictions/0000587.png (deflated 25%)
# updating: content/predictions/0000113.png (deflated 25%)
# updating: content/predictions/0000693.png (deflated 24%)
# updating: content/predictions/0000894.png (deflated 24%)
# updating: content/predictions/0000802.png (deflated 23%)
# updating: content/predictions/0000927.png (deflated 25%)
# updating: content/predictions/0000568.png (deflated 25%)
# updating: content/predictions/0000686.png (deflated 24%)
# updating: content/predictions/0000606.png (deflated 25%)
# updating: content/predictions/0000292.png (deflated 24%)
# updating: content/predictions/0000548.png (deflated 24%)
# updating: content/predictions/0001025.png (deflated 25%)
# updating: content/predictions/0000655.png (deflated 25%)
# updating: content/predictions/0000464.png (deflated 25%)
# updating: content/predictions/0000978.png (deflated 24%)
# updating: content/predictions/0000884.png (deflated 23%)
# updating: content/predictions/0000617.png (deflated 25%)
# updating: content/predictions/0000405.png (deflated 25%)
# updating: content/predictions/0000220.png (deflated 23%)
# updating: content/predictions/0000601.png (deflated 24%)
# updating: content/predictions/0000980.png (deflated 25%)
# updating: content/predictions/0000696.png (deflated 23%)
# updating: content/predictions/0000557.png (deflated 25%)
# updating: content/predictions/0000158.png (deflated 27%)
# updating: content/predictions/0000824.png (deflated 24%)
# updating: content/predictions/0000474.png (deflated 26%)
# updating: content/predictions/0000714.png (deflated 23%)
# updating: content/predictions/0000352.png (deflated 25%)
# updating: content/predictions/0000442.png (deflated 25%)
# updating: content/predictions/0000563.png (deflated 27%)
# updating: content/predictions/0000533.png (deflated 24%)
# updating: content/predictions/0000177.png (deflated 25%)
# updating: content/predictions/0000332.png (deflated 25%)
# updating: content/predictions/0000127.png (deflated 22%)
# updating: content/predictions/0000485.png (deflated 23%)
# updating: content/predictions/0000599.png (deflated 25%)
# updating: content/predictions/0000238.png (deflated 25%)
# updating: content/predictions/0000388.png (deflated 23%)
# updating: content/predictions/0000492.png (deflated 25%)
# updating: content/predictions/0000664.png (deflated 23%)
# updating: content/predictions/0000237.png (deflated 25%)
# updating: content/predictions/0000983.png (deflated 24%)
# updating: content/predictions/0000973.png (deflated 25%)
# updating: content/predictions/0000799.png (deflated 23%)
# updating: content/predictions/0000399.png (deflated 25%)
# updating: content/predictions/0000448.png (deflated 26%)
# updating: content/predictions/0000290.png (deflated 25%)
# updating: content/predictions/0000657.png (deflated 25%)
# updating: content/predictions/0000462.png (deflated 24%)
# updating: content/predictions/0000221.png (deflated 23%)
# updating: content/predictions/0000941.png (deflated 23%)
# updating: content/predictions/0000616.png (deflated 24%)
# updating: content/predictions/0000272.png (deflated 23%)
# updating: content/predictions/0000285.png (deflated 24%)
# updating: content/predictions/0000852.png (deflated 25%)
# updating: content/predictions/0000940.png (deflated 24%)
# updating: content/predictions/0000331.png (deflated 25%)
# updating: content/predictions/0000205.png (deflated 26%)
# updating: content/predictions/0000188.png (deflated 25%)
# updating: content/predictions/0000481.png (deflated 23%)
# updating: content/predictions/0000794.png (deflated 23%)
# updating: content/predictions/0000597.png (deflated 25%)
# updating: content/predictions/0000295.png (deflated 24%)
# updating: content/predictions/0000795.png (deflated 24%)
# updating: content/predictions/0000278.png (deflated 23%)
# updating: content/predictions/0000651.png (deflated 24%)
# updating: content/predictions/0000887.png (deflated 24%)
# updating: content/predictions/0000684.png (deflated 24%)
# updating: content/predictions/0000741.png (deflated 23%)
# updating: content/predictions/0000569.png (deflated 25%)
# updating: content/predictions/0000636.png (deflated 25%)
# updating: content/predictions/0000546.png (deflated 25%)
# updating: content/predictions/0000692.png (deflated 24%)
# updating: content/predictions/0001038.png (deflated 24%)
# updating: content/predictions/0000360.png (deflated 25%)
# updating: content/predictions/0000219.png (deflated 25%)
# updating: content/predictions/0001048.png (deflated 23%)
# updating: content/predictions/0000345.png (deflated 24%)
# updating: content/predictions/0000985.png (deflated 26%)
# updating: content/predictions/0000835.png (deflated 23%)
# updating: content/predictions/0000776.png (deflated 24%)
# updating: content/predictions/0000122.png (deflated 23%)
# updating: content/predictions/0000813.png (deflated 25%)
# updating: content/predictions/0000247.png (deflated 24%)
# updating: content/predictions/0000162.png (deflated 25%)
# updating: content/predictions/0000248.png (deflated 23%)
# updating: content/predictions/0000201.png (deflated 25%)
# updating: content/predictions/0000192.png (deflated 25%)
# updating: content/predictions/0000527.png (deflated 24%)
# updating: content/predictions/0000538.png (deflated 24%)
# updating: content/predictions/0000117.png (deflated 22%)
# updating: content/predictions/0000518.png (deflated 24%)
# updating: content/predictions/0000376.png (deflated 24%)
# updating: content/predictions/0000577.png (deflated 24%)
# updating: content/predictions/0000998.png (deflated 26%)
# updating: content/predictions/0000328.png (deflated 25%)
# updating: content/predictions/0000982.png (deflated 24%)
# updating: content/predictions/0000062.png (deflated 24%)
# updating: content/predictions/0000820.png (deflated 25%)
# updating: content/predictions/0000118.png (deflated 23%)
# updating: content/predictions/0000620.png (deflated 24%)
# updating: content/predictions/0000912.png (deflated 23%)
# updating: content/predictions/0000740.png (deflated 23%)
# updating: content/predictions/0000932.png (deflated 22%)
# updating: content/predictions/0000535.png (deflated 24%)
# updating: content/predictions/0000727.png (deflated 24%)
# updating: content/predictions/0000417.png (deflated 25%)
# updating: content/predictions/0000697.png (deflated 24%)
# updating: content/predictions/0000179.png (deflated 25%)
# updating: content/predictions/0000751.png (deflated 23%)
# updating: content/predictions/0001029.png (deflated 24%)
# updating: content/predictions/0000468.png (deflated 26%)
# updating: content/predictions/0000805.png (deflated 27%)
# updating: content/predictions/0000613.png (deflated 24%)
# updating: content/predictions/0000899.png (deflated 25%)
# updating: content/predictions/0000746.png (deflated 22%)
# updating: content/predictions/0001049.png (deflated 24%)
# updating: content/predictions/0000218.png (deflated 25%)
# updating: content/predictions/0000992.png (deflated 27%)
# updating: content/predictions/0000450.png (deflated 25%)
# updating: content/predictions/0000414.png (deflated 25%)
# updating: content/predictions/0000756.png (deflated 25%)
# updating: content/predictions/0000847.png (deflated 23%)
# updating: content/predictions/0000379.png (deflated 24%)
# updating: content/predictions/0000170.png (deflated 25%)
# updating: content/predictions/0000240.png (deflated 24%)
# updating: content/predictions/0000453.png (deflated 25%)
# updating: content/predictions/0000344.png (deflated 24%)
# updating: content/predictions/0000928.png (deflated 24%)
# updating: content/predictions/0000501.png (deflated 24%)
# updating: content/predictions/0000176.png (deflated 25%)
# updating: content/predictions/0000831.png (deflated 24%)
# updating: content/predictions/0000788.png (deflated 24%)
# updating: content/predictions/0000086.png (deflated 25%)
# updating: content/predictions/0000204.png (deflated 25%)
# updating: content/predictions/0000792.png (deflated 23%)
# updating: content/predictions/0000910.png (deflated 25%)
# updating: content/predictions/0000288.png (deflated 24%)
# updating: content/predictions/0000096.png (deflated 25%)
# updating: content/predictions/0000227.png (deflated 25%)
# updating: content/predictions/0000472.png (deflated 25%)
# updating: content/predictions/0000446.png (deflated 26%)
# updating: content/predictions/0000289.png (deflated 24%)
# updating: content/predictions/0000744.png (deflated 22%)
# updating: content/predictions/0000111.png (deflated 24%)
# updating: content/predictions/0000471.png (deflated 25%)
# updating: content/predictions/0000969.png (deflated 25%)
# updating: content/predictions/0000765.png (deflated 24%)
# updating: content/predictions/0000251.png (deflated 23%)
# updating: content/predictions/0001010.png (deflated 24%)
# updating: content/predictions/0000112.png (deflated 24%)
# updating: content/predictions/0000079.png (deflated 25%)
# updating: content/predictions/0000337.png (deflated 26%)
# updating: content/predictions/0001026.png (deflated 24%)
# updating: content/predictions/0000797.png (deflated 23%)
# updating: content/predictions/0000147.png (deflated 24%)
# updating: content/predictions/0000566.png (deflated 25%)
# updating: content/predictions/0000558.png (deflated 26%)
# updating: content/predictions/0000689.png (deflated 25%)
# updating: content/predictions/0000101.png (deflated 24%)
# updating: content/predictions/0000092.png (deflated 26%)
# updating: content/predictions/0000809.png (deflated 25%)
# updating: content/predictions/0000447.png (deflated 26%)
# updating: content/predictions/0000124.png (deflated 22%)
# updating: content/predictions/0000224.png (deflated 24%)
# updating: content/predictions/0000371.png (deflated 25%)
# updating: content/predictions/0000772.png (deflated 24%)
# updating: content/predictions/0000076.png (deflated 25%)
# updating: content/predictions/0000534.png (deflated 24%)
# updating: content/predictions/0000354.png (deflated 25%)
# updating: content/predictions/0000923.png (deflated 26%)
# updating: content/predictions/0000131.png (deflated 22%)
# updating: content/predictions/0000685.png (deflated 24%)
# updating: content/predictions/0000957.png (deflated 26%)
# updating: content/predictions/0000172.png (deflated 24%)
# updating: content/predictions/0000550.png (deflated 25%)
# updating: content/predictions/0000638.png (deflated 25%)
# updating: content/predictions/0000679.png (deflated 23%)
# updating: content/predictions/0000951.png (deflated 25%)
# updating: content/predictions/0000390.png (deflated 25%)
# updating: content/predictions/0000223.png (deflated 23%)
# updating: content/predictions/0000671.png (deflated 24%)
# updating: content/predictions/0000493.png (deflated 26%)
# updating: content/predictions/0000590.png (deflated 26%)
# updating: content/predictions/0000398.png (deflated 25%)
# updating: content/predictions/0000984.png (deflated 24%)
# updating: content/predictions/0000387.png (deflated 23%)
# updating: content/predictions/0000293.png (deflated 24%)
# updating: content/predictions/0000672.png (deflated 24%)
# updating: content/predictions/0000457.png (deflated 26%)
# updating: content/predictions/0000540.png (deflated 25%)
# updating: content/predictions/0000274.png (deflated 24%)
# updating: content/predictions/0000273.png (deflated 23%)
# updating: content/predictions/0001035.png (deflated 23%)
# updating: content/predictions/0001058.png (deflated 24%)
# updating: content/predictions/0000291.png (deflated 24%)
# updating: content/predictions/0000754.png (deflated 24%)
# updating: content/predictions/0000964.png (deflated 26%)
# updating: content/predictions/0000945.png (deflated 23%)
# updating: content/predictions/0000346.png (deflated 25%)
# updating: content/predictions/0000592.png (deflated 25%)
# updating: content/predictions/0000507.png (deflated 25%)
# updating: content/predictions/0000303.png (deflated 24%)
# updating: content/predictions/0000250.png (deflated 22%)
# updating: content/predictions/0000634.png (deflated 23%)
# updating: content/predictions/0000745.png (deflated 23%)
# updating: content/predictions/0000796.png (deflated 23%)
# updating: content/predictions/0000298.png (deflated 24%)
# updating: content/predictions/0000469.png (deflated 26%)
# updating: content/predictions/0000246.png (deflated 24%)
# updating: content/predictions/0000682.png (deflated 24%)
# updating: content/predictions/0000365.png (deflated 25%)
# updating: content/predictions/0000186.png (deflated 25%)
# updating: content/predictions/0000971.png (deflated 25%)
# updating: content/predictions/0000770.png (deflated 25%)
# updating: content/predictions/0000883.png (deflated 23%)
# updating: content/predictions/0000607.png (deflated 25%)
# updating: content/predictions/0000958.png (deflated 25%)
# updating: content/predictions/0000823.png (deflated 23%)
# updating: content/predictions/0000145.png (deflated 24%)
# updating: content/predictions/0000830.png (deflated 23%)
# updating: content/predictions/0000575.png (deflated 25%)
# updating: content/predictions/0000623.png (deflated 24%)
# updating: content/predictions/0000475.png (deflated 25%)
# updating: content/predictions/0000245.png (deflated 25%)
# updating: content/predictions/0000715.png (deflated 22%)
# updating: content/predictions/0000074.png (deflated 25%)
# updating: content/predictions/0000942.png (deflated 24%)
# updating: content/predictions/0000743.png (deflated 22%)
# updating: content/predictions/0000943.png (deflated 24%)
# updating: content/predictions/0000310.png (deflated 25%)
# updating: content/predictions/0000775.png (deflated 24%)
# updating: content/predictions/0000974.png (deflated 24%)
# updating: content/predictions/0000517.png (deflated 24%)
# updating: content/predictions/0000539.png (deflated 24%)
# updating: content/predictions/0000991.png (deflated 28%)
# updating: content/predictions/0000257.png (deflated 22%)
# updating: content/predictions/0000185.png (deflated 25%)
# updating: content/predictions/0000919.png (deflated 26%)
# updating: content/predictions/0000249.png (deflated 24%)
# updating: content/predictions/0000263.png (deflated 25%)
# updating: content/predictions/0000335.png (deflated 27%)
# updating: content/predictions/0000317.png (deflated 25%)
# updating: content/predictions/0000149.png (deflated 24%)
# updating: content/predictions/0000593.png (deflated 24%)
# updating: content/predictions/0000999.png (deflated 25%)
# updating: content/predictions/0000215.png (deflated 24%)
# updating: content/predictions/0000380.png (deflated 24%)
# updating: content/predictions/0000694.png (deflated 25%)

# %%
from google.colab import files
files.download('predictions.zip')
